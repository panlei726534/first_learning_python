# %% [markdown]
# <a href="https://colab.research.google.com/github/panlei726534/first_learning_python/blob/master/myfirst_pyhone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(*np.random.randn(2,1000))
